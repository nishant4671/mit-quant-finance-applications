# %% [markdown]
# # 🧪 Sandbox — Quick Experiments
#
# Use this notebook as a **scratchpad** to test small snippets of code.
# Don't worry about keeping it clean — that's the whole point.
#
# ---

# %%
# Common imports — run this cell first
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats

# %matplotlib inline
plt.style.use('seaborn-v0_8-whitegrid')
print('Ready to go! ✅')

# %%
# Scratch cell — experiment here

# %%
# Another scratch cell
